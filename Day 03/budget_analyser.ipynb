# %% [markdown]
# # Salary Analyser
# analysing and forecasting the budget

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import pandas as pd
from sklearn.model_selection import train_test_split
import joblib
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn import preprocessing
from scipy import stats
import numpy

# %%
budget_data = pd.read_csv("salary.csv")

# getting the input data set
x = budget_data.drop(columns=["Salary"])
y = budget_data["Salary"]

plt.scatter(x,y)
plt.xlabel("Years of experience")
plt.ylabel("Salary")

px = numpy.array(x).reshape(1,35)

slope, intercept, r, p, stderr = stats.linregress(px,y)

def determineTheLinearityForEveryX(dataX):
    return slope * float(dataX) + intercept

yintercept = list(map(determineTheLinearityForEveryX,x.values))
plt.plot(x,yintercept)
plt.show()

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

dmodel = DecisionTreeClassifier()
dmodel.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.9/site-packages/scipy/stats/_stats_mstats_common.py:189: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /usr/local/lib/python3.9/site-packages/scipy/stats/_stats_mstats_common.py:192: RuntimeWarning: invalid value encountered in sqrt
#   slope_stderr = np.sqrt((1 - r**2) * ssym / ssxm / df)
# DecisionTreeClassifier()

# %%
print(dmodel.predict(x_test))
# Out:
# [109431  54445  98273  55794]

# %%
fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()
