# %% [markdown]
# ## Supervised Learning

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Reading data from the file

# %%
dataframe = pd.read_csv('bp-data.csv')

# %%
dataframe.head()
# Out:
#    Patient_Number  Level_of_Hemoglobin  Genetic_Pedigree_Coefficient  Age  \
# 0               1                11.28                          0.90   34
# 1               2                 9.75                          0.23   54
# 2               3                10.79                          0.91   70
# 3               4                11.00                          0.43   71
# 4               5                14.17                          0.83   52
#
#    BMI  Sex  Pregnancy  Smoking  Physical_activity  salt_content_in_the_diet  \
# 0   23    1        1.0        0              45961                     48071
# 1   33    1        NaN        0              26106                     25333
# 2   49    0        NaN        0               9995                     29465
# 3   50    0        NaN        0              10635                      7439
# 4   19    0        NaN        0              15619                     49644
#
# ...

# %%
for label in dataframe.columns:
    plt.hist(dataframe[dataframe['Blood_Pressure_Abnormality']==1][label],label='gamma', color='blue', alpha=0.7)
    plt.hist(dataframe[dataframe['Blood_Pressure_Abnormality']==0][label],label='ha', color='red', alpha=0.7)

# %% [markdown]
# ### Preparing the dataset

# %%
train,valid,test = np.split(dataframe.sample(frac=1),[int(0.6 * len(dataframe)),int(0.8 * len(dataframe))])

# %%
valid.head()
# Out:
#       Patient_Number  Level_of_Hemoglobin  Genetic_Pedigree_Coefficient  Age  \
# 1102            1103                11.33                          0.62   29
# 1883            1884                10.35                          0.88   25
# 1424            1425                 9.54                          0.21   72
# 1369            1370                10.26                          0.31   51
# 492              493                12.87                          0.29   61
#
#       BMI  Sex  Pregnancy  Smoking  Physical_activity  \
# 1102   21    1        1.0        1              14017
# 1883   14    0        NaN        0              19382
# 1424   25    1        NaN        1              43600
# 1369   10    1        NaN        1              33405
# 492    23    0        NaN        0               1723
#
#       salt_content_in_the_diet  alcohol_consumption_per_day  Level_of_Stress  \
# 1102                     37515                        345.0                1
# ...
